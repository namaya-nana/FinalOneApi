# %%
! chmod 755 q; chmod 755 run_gpu.sh;if [ -x "$(command -v qsub)" ]; then ./q run_gpu.sh; else ./run_gpu.sh; fi
# Out:
# ## u0068f821c48e34a98dc6c80a500121f Se está compilando Transformada de Fourier en paralelo- 1 of 7 transfo_fourier.cpp
# Ejecutando en dispositivo: Intel(R) Data Center GPU Max 1100
# Tiempo de ejecución paralelo: 0.0862212 segundos.
# Transformada de Fourier realizada!
# Resultado[0]: (0,0)
# Resultado[1]: (1,1)
# Resultado[2]: (2,2)
# Resultado[3]: (3,3)
# Resultado[4]: (4,4)
# Resultado[5]: (5,5)
# Resultado[6]: (6,6)
# Resultado[7]: (7,7)
# Resultado[8]: (8,8)
# Resultado[9]: (9,9)
# Resultado[10]: (10,10)
# Resultado[11]: (11,11)
# Resultado[12]: (12,12)
# Resultado[13]: (13,13)
# Resultado[14]: (14,14)
# Resultado[15]: (15,15)
# Resultado[16]: (16,16)
# Resultado[17]: (17,17)
# Resultado[18]: (18,18)
# Resultado[19]: (19,19)
# Resultado[20]: (20,20)
# Resultado[21]: (21,21)
# Resultado[22]: (22,22)
# Resultado[23]: (23,23)
# Resultado[24]: (24,24)
# Resultado[25]: (25,25)
# Resultado[26]: (26,26)
# Resultado[27]: (27,27)
# Resultado[28]: (28,28)
# Resultado[29]: (29,29)
# ...
